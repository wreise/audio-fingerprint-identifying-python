# %%
# %load_ext autoreload
# %autoreload 2

# %%
from libs.db_sqlite import SqliteDatabase
from argparse import RawTextHelpFormatter
from itertools import zip_longest
from termcolor import colored
from libs.config import get_config
from libs.reader_file import FileReader
from libs import fingerprint

import matplotlib.pyplot as plt

# %% [markdown]
# # Deal with db

# %%
config = get_config()
db = SqliteDatabase()
# Out:
# sqlite - connection opened

# %% [markdown]
# # Get file

# %%
filename = '00 - Easily.mp3'
path = 'mp3/'

# %%
reader = FileReader(path + filename)
audio = reader.parse_audio()
song = db.get_song_by_filehash(audio['file_hash'])
song_id = db.add_song(filename, audio['file_hash'])

# %%
data = audio['channels']
Fs = fingerprint.DEFAULT_FS
channel_amount = len(data)

# %%
def grouper(iterable, n, fillvalue=None):
    args = [iter(iterable)] * n
    return [list(filter(None, values)) for values
            in zip_longest(fillvalue=fillvalue, *args)]

def find_matches(samples, Fs=fingerprint.DEFAULT_FS):
    hashes = fingerprint.fingerprint(samples, Fs=Fs)
    return return_matches(hashes)

def return_matches(hashes):
    mapper = {}
    for hash, offset in hashes:
        mapper[hash.upper()] = offset
    values = mapper.keys()
    
    for split_values in grouper(values, 1000):
        # @todo move to db related files
        query = """
            SELECT upper(hash), song_fk, offset
            FROM fingerprints
            WHERE upper(hash) IN (%s)
          """
        query = query % ', '.join('?' * len(split_values))
        x = db.executeAll(query, split_values)
        matches_found = len(x)
        
        if matches_found > 0:
            msg = '   ** found %d hash matches (step %d/%d)'
            print(colored(msg, 'green') % (
              matches_found,
              -1,
              len(values)
            ))
        else:
            msg = '   ** not matches found (step %d/%d)'
            print(colored(msg, 'red') % (
              len(split_values),
              len(values)
            ))
        for hash, sid, offset in x:
            # (sid, db_offset - song_sampled_offset)
            yield (sid, offset - mapper[hash])

def align_matches(matches):
    diff_counter = {}
    largest = 0
    largest_count = 0
    song_id = -1
    for tup in matches:
        sid, diff = tup
        
        if diff not in diff_counter:
            diff_counter[diff] = {}
        
        if sid not in diff_counter[diff]:
            diff_counter[diff][sid] = 0
        
        diff_counter[diff][sid] += 1
        
        if diff_counter[diff][sid] > largest_count:
            largest = diff
            largest_count = diff_counter[diff][sid]
            song_id = sid
    
    songM = db.get_song_by_id(song_id)
    
    nseconds = round(float(largest) / fingerprint.DEFAULT_FS *
                     fingerprint.DEFAULT_WINDOW_SIZE *
                     fingerprint.DEFAULT_OVERLAP_RATIO, 5)

    return {
        "SONG_ID" : song_id,
        "SONG_NAME" : songM[1],
        "CONFIDENCE" : largest_count,
        "OFFSET" : int(largest),
        "OFFSET_SECS" : nseconds
    }

# %% [raw]
# matches = []
# for channeln, channel in enumerate(data):
#         # TODO: Remove prints or change them into optional logging.
#         matches.extend(find_matches(channel))
#
#         msg = '   finished channel %d/%d, got %d hashes'
#         print(colored(msg, attrs=['dark']) % (
#           channeln+1, channel_amount, len(matches)
#         ))

# %% [markdown]
# # Manual

# %%
sample = [11,50]

# %%
hashes = list(fingerprint.fingerprint(data[0][Fs*sample[0]: Fs*sample[1]], Fs=Fs))
# Out:
#    local_maxima: 1354 of frequency & time pairs

# %%
matches = return_matches(hashes=hashes)

# %%
m = [h for h in matches]
# Out:
#    ** found 4 hash matches (step -1/18767)
#    ** found 2 hash matches (step -1/18767)
#    ** not matches found (step 1000/18767)
#    ** found 3 hash matches (step -1/18767)
#    ** found 1 hash matches (step -1/18767)
#    ** found 1 hash matches (step -1/18767)
#    ** found 3 hash matches (step -1/18767)
#    ** found 1 hash matches (step -1/18767)
#    ** found 2 hash matches (step -1/18767)
#    ** found 2 hash matches (step -1/18767)
#    ** not matches found (step 1000/18767)
#    ** found 3 hash matches (step -1/18767)
#    ** not matches found (step 1000/18767)
#    ** found 5 hash matches (step -1/18767)
#    ** found 2 hash matches (step -1/18767)
#    ** found 4 hash matches (step -1/18767)
#    ** found 1 hash matches (step -1/18767)
#    ** found 3 hash matches (step -1/18767)
#    ** found 3 hash matches (step -1/18767)

# %%
align_matches(m)
# Out:
# {'SONG_ID': 1,
#  'SONG_NAME': '00 - Easily.mp3',
#  'CONFIDENCE': 1,
#  'OFFSET': 961,
#  'OFFSET_SECS': 44.62875}

# %%
dict_hashes = {h: hv for (h, hv) in hashes}

# %%
nb = 100000
query = """
            SELECT upper(hash), song_fk, offset
            FROM fingerprints
            WHERE upper(hash) IN (%s)
          """
query = query % ', '.join('?' * nb)
db.executeAll(query, [k[0] for k, _ in zip(hashes, range(nb))])
# Out:
# [('48752978135356367235', 1, b'\xe9\x02\x00\x00\x00\x00\x00\x00'),
#  ('05835073779111655026', 1, b'\x99\x03\x00\x00\x00\x00\x00\x00'),
#  ('90195636954544455046', 1, b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  ('03522669584382427413', 1, b'\x13\x04\x00\x00\x00\x00\x00\x00'),
#  ('73021731275182487565', 1, b'\x0b\x04\x00\x00\x00\x00\x00\x00'),
#  ('23921454263754211485', 1, b'\x98\x03\x00\x00\x00\x00\x00\x00'),
#  ('65299988631383985027', 1, b'\xf7\x06\x00\x00\x00\x00\x00\x00')]

# %%
[k[0] for k, _ in zip(hashes, range(nb))]
# Out:
# ['0f1c672282b5bd31d61e',
#  '146371d65e18cd933439',
#  '92f9d27f3d30df5c008b',
#  '9d4b94570705f57a6a71',
#  '2930e18edff7df47135e',
#  '5017991fe520d5f1c9d8',
#  'e8c34c9de10293473a5c',
#  '92b4adb682473546e183',
#  '36dccc22a96aa2f6a89d',
#  'f86d955ebc8aa05834db',
#  'b9b4d269b9c20a48a57f',
#  'acd9435169a3a95af0aa',
#  '4cd9f46ea6ecb47ffa9e',
#  'ff31d9d098f528271835',
#  '3fb25445f6b210c08093',
#  'b89dd72f4ac60a2f7909',
#  '6e5d722e3cda4aafd1e6',
#  'c1683ac4f8de135a887e',
#  'a402dc5a5c378f2def61',
#  'b83e53c53b3215576d94',
#  '9cc9cb6d6090098298d8',
#  '36db9d1ed125f10c35cf',
#  '1214843364687d987a96',
#  'b58b21fd996372190441',
#  '036cae402432696a3cb1',
#  '58a4de5e594724d2dc7f',
#  '1ec3e3a176f20d90654a',
#  'eab415127364dcacb679',
#  'ca07ffe02ae616ff993e',
#  '7cbdd6a78115aa793300',
#  '11877b8707c68cf91d0e',
#  '3aa5db84a1b3e3dbda45',
#  '77271232258d88313803',
#  'c4463582578becee091a',
#  '177e6aebe07b58452271',
#  '43e8bc268ecbd8756ee2',
#  'e9b39446ec6d5ef48187',
#  '851d138a9ff15deb4ede',
#  'eab83ecf78e97c5481e9',
#  '59528a5fcd98c6bb2101',
#  '4268ffcb7646bd1fb75e',
#  '992656ffbb83b2641956',
#  '59d144ae5f22217e74ba',
#  'b57d1b86efda4eb2b548',
#  'e4f24d83f99df01b70d1',
#  'bb0030a0ce02665ae3b1',
#  '8bb7974ca5b37c81db7e',
#  'd418034cfbc9e0b4fb7a',
#  '63ad56fcf84769454c7f',
#  '0a0d8ef427d8b4791f7d',
#  '45d44244171f7d03e3f9',
#  '30d1822e0075ddf5a28c',
#  'bf861ed8f8366aa21a99',
#  '84f29b1c7f0b5aeac3ee',
#  '75a10bd71019512beb03',
#  'f435f99a434c8337e748',
#  '72ade78948b3bd3b6206',
#  '85e8198d39ffb63782b7',
#  '81fbb31bd7052aba025a',
#  '9f623955acd6dd629ca1',
#  '135d6399555aea0d5124',
#  'd87cf969c4b45c32355c',
#  'aae4bfc5d6d0766d6383',
#  'c563e90402b4af4f5c37',
#  '6e6a12487573d1f9b49e',
#  'ce810ebf7ed0d840e5ce',
#  'fe4cc60642fb30ac9bce',
#  '4b82025a416e0a8a1b75',
#  '4513323901214007b01d',
#  'f6ed42030111aed0dcd8',
#  '9c95c2605a158c490338',
#  'd2a1b448594e0d660e7b',
#  '3b5a062a4c9fec85a413',
#  'f657c68ed807411ab57f',
#  'eb3af33811f1663f053e',
#  'e7154b44d8eb4892745b',
#  '2dfe5bad7dedf881173f',
#  '48bead939c8908851ef6',
#  '8f4f602bb17919a044a3',
#  '8eac70be8c5dd611aacf',
#  '62778967be07854bdab9',
#  '4126ec0ce866b43b872e',
#  '61d8df26037e995d851e',
#  '616fa07287eff51d2545',
#  'bbf0220dc3f63e8fc6ef',
#  '9bf5da65a09e93c4de36',
#  'a1015e0212da12a3bc0e',
#  '897b518078e92d3b4543',
#  'c4aa8b303b3b25734f34',
#  '8bbbafe3c19c629e177a',
#  'e90d01847772ead3cb80',
#  '23499496b6ab05e00ab8',
#  '7529116dbcd42a9239cb',
#  'e810cea9dc00eefddd5d',
#  '140b40b476f30f63369d',
#  'e94fddf2892ad697875c',
#  'a733b03a152fed7adb79',
#  '45343289b88f143e8f33',
#  'bf9980a4c29a36dcc637',
#  '837c57c3aaf71fbf000e',
#  '995134c1d6a4de302b3d',
#  '6a1da40c5e7ec8aaeb3c',
#  '4a06e9ce1222b9fef341',
#  '90a18f60b55747275837',
#  'c5e4195c2bafaecf832b',
#  'c116a011d1b30b6c6d46',
#  '097e9599c5e8c8b7ce81',
#  '627dcc1c1ed5683570af',
#  '9b59337f247bd52b3b55',
#  'e863d2906726be52074e',
#  'f5a024d950c21ac91845',
#  '361cff52316dc769d93e',
#  '187c20245b5f87115959',
#  'bf820cd3aadd526b742e',
#  '1cdb8b2b407d043f24bd',
#  '5f5c64e272a9f9cf2e9d',
#  '74fb212d52016aab0d8d',
#  '8c89063e4881742b2a30',
#  '528ccaf799f5d9e3e84e',
#  '5b74156e43f25f73b371',
#  '3375cbc931dc20b0cd81',
#  '26304d7509a17de1fe51',
#  'd77e7793c89a1cc3945f',
#  'a3bb3cbe847a0892043e',
#  '5818c8a2104c03215f79',
#  '7cdbf9cefddf29ce2112',
#  'b3974882b160d8cdd87c',
#  'dcf547c204ad47c0dc42',
#  '451235faa20c4d00a239',
#  '75044da30ce114d300fd',
#  'cd346be023a083fccf8a',
#  'e7bd7708f80d4dece647',
#  'da5bd9c819c80732ad57',
#  'd08321de4bcb55337bc6',
#  '9c4aaeb7242ff0103bc1',
#  'a6576866d4e8a5812912',
#  'f311b27efa74332cd412',
#  '4635fbafe7a3cd9be503',
#  'db4e7710c71dfca448d7',
#  'eb1895e9df3242af7939',
#  '65f20d1b282e2f393177',
#  '7edb34f58d30b3c67b44',
#  'fa5a554d2c71018cd8cc',
#  'a981ebd79ea83bcb64ff',
#  '10413abcb953c9963cd7',
#  '859ec07dac5351bf8fc5',
#  '31fdeb1c42dce19ef9b1',
#  'c2955afa03c54eae409f',
#  'cae15af882c36414b693',
#  '24aa48ad2e2604e6244b',
#  'e58f4cee51da54fde29a',
#  'd01b490b4c2f7892ecbf',
#  '2d229e5db9c31bed6c65',
#  '19a7aa55c79bb1e9eac2',
#  'e8b4246726e6c684ae94',
#  'aa15bc2a498d5b75d874',
#  '1998a39ac7ff3bf798ff',
#  '850a69baa16328c42edc',
#  '9148673c0f2b804c3850',
#  '6ef542b1b537f2b1426e',
#  'f748452d1c5538d496c5',
#  '7909f5fc44dc51a5cecf',
#  '611926ab8d4f3cf0be5e',
#  'beb4bec4af7695afefcc',
#  '1694ec94dc3eee93acd3',
#  'bfa6501be85bd5f50695',
#  '0f787a5b62f0c2fe5b57',
#  'd3271826e93c6f8bf908',
#  '50d056601ecee1e55640',
#  '6a950c57e37d34c66266',
#  '6521b9683a09349bc101',
#  'd1d1da3f0251257e59fa',
#  'c4bee4f73ab00126c0b2',
#  'b7e926630ba46000e63b',
#  '63b11f97e1f1a158028d',
#  '91e3aba2fc72676353d5',
#  'e4ba2230c89629ac92ef',
#  'da42f2f0bb4d941d307b',
#  'bb752c59c0010ffd1578',
#  'c23c024c5fc9ab2c0928',
#  'd7c93c9fee714e9be330',
#  'ae9aef26cc9a88fb4326',
#  '38c476b7823e7ec5448a',
#  '0bc5479462c608cd5333',
#  'bda2bdc8c2c1098b5128',
#  '8a51ee15d730fdbe506a',
#  'b299933748bf5785015c',
#  '632805b6dc53a983eaf6',
#  '8d709fe6b76e00e2568e',
#  '663e87628954362df143',
#  '7f98a3aaba30e5edae1b',
#  '966ef9c6017b2dfa8349',
#  '80ed91c485b043f0392b',
#  'e642bca8cc3e7a0578f0',
#  '0a93c2891f3e668c3217',
#  '5f4007f90de0f8422393',
#  '226d23dbda6a22d576bf',
#  'ebe12988e4ebfb998b97',
#  '8b0b46104905822e6a46',
#  '22b8b00bde220109d7d1',
#  'b6386b8a3dff0c21d048',
#  '7134307f4b43cc0c8b4e',
#  '084d3d2e8a7147f9bdb5',
#  '190618b0310861c6cdf4',
#  'b86dc326335fe9b8a7f7',
#  '8f45b9dba7670d78ce1a',
#  'fa1d342c3d09079afc5f',
#  '91cc91f8f0baab55350f',
#  'de589b8222c828fb8968',
#  '69fcc47666eda4e8e832',
#  'cada0ef62b0c0d16bc10',
#  'a1e0ea96f24ed504d117',
#  'bb69ed95b38c670d8002',
#  'a2bfbd5f9f872d553cb1',
#  'c43a48dfd8abf4fabab2',
#  '7cfd76a67aea5fd9816f',
#  '98b123cc74b5ced9c150',
#  '31657b501386535c43e9',
#  '86c9ef54e8b6c3d63253',
#  '5579b03d2a70f02a5f29',
#  '53d66c7c1167a01fdaea',
#  'd6502c86795362bebcb6',
#  '8730f8b69649f02fddb8',
#  '11dde04b732d6fc83a9c',
#  '81ebc190c49c66fc822f',
#  'a540e3fecf8e941c02f2',
#  'f71d9bab0a503334d4ab',
#  'ed31f8e76fa5869d61ce',
#  '8fa3286be176205c8dc0',
#  '5f713cdd6d8ef20960b3',
#  '364530495d2aec26ba3e',
#  '19e84ae399575f7edc32',
#  'b1f1264f86366f69dbdc',
#  'b2d2398c92a8aea178f7',
#  '02c497e1ea2ef6f78007',
#  '0d2d7321ad9e2be65706',
#  'e1c65679fe2dfd7441e8',
#  'de0f7a4e483f9acc9d5b',
#  '02406c56a840ef4048b2',
#  '2da383d4b84a54600369',
#  '6d2f6772707b90eebc07',
#  'df6f3645884c9a156b34',
#  '7e2df8af3c01281fd1c0',
#  '9af22724c3bcfe1424f5',
#  'ed399d107fa83214182f',
#  'c9fe7bfe26fc0f73731a',
#  'a5a2c4a8223c71a1dd9a',
#  '1ea68b25edff923632df',
#  '252fd488fdbef5a3bf99',
#  '8500b3e8388c82767b03',
#  'bf7fb50cd77ee2d06b40',
#  '77d45cd6e522bb280788',
#  'cf2fe59a1db89c7654c5',
#  'adc5007598efedd67abe',
#  '64bf18afc1e8a6787c61',
#  '32fb5924584e0da2f616',
#  '0441e8ceb518f7d1560c',
#  '7996100cc691376fb11e',
#  'c3cbe2222ccd12d179a6',
#  'c72b6ff5f7431ce436fd',
#  '8ea1dbd2136dc190b4a3',
#  'c7555583ac14d879731e',
#  '2b796aa459d8d16a6585',
#  '12f4eb7bd8558d513cf7',
#  '967c1827a7b0c4d8d7c0',
#  '519d8412a2dbd19b8b00',
#  'e4a73e0ea096bcb39460',
#  'a5537fc4cc36c67e6d0e',
#  '16144f302952bf2dec2e',
#  '2adf688f02d4fe923127',
#  '9815ba37da708e620bc2',
#  '72b62bbfb81824dea595',
#  'bcf4125b6c5249e4c565',
#  'd6d509b486134a14ad94',
#  '9e0568baf75942814a67',
#  'b18234eae8848b8d2db3',
#  '2cbb675265f25b9ce016',
#  'bd8379e0da586e0ebe8b',
#  'ece575139be2c958856b',
#  '77dab388d6f4d732184b',
#  '33d89116b3aab4a25874',
#  'df560538162e960bcf82',
#  'dfa051545970577cef8e',
#  '63649a6b426155e4b665',
#  'f922d6d6086a4948d041',
#  '7bbbba8dc58c30a09da3',
#  'fd3aed7cb2d15240f555',
#  '19e9be7273d30e7c0447',
#  '2bc651acda81b12978c0',
#  '6fe0ccc3313facbe7c08',
#  '87f73e6fc26e3e7892ad',
#  '95c1dae5a7803e829688',
#  '7d9111d1459b6c860b3c',
#  'ea77953d53c5c0e244e2',
#  '408b38340a2cd753fbac',
#  '7091c37c4b657a1d4b1d',
#  '6b6baba54f1b6ddcadad',
#  'ecaafcdd7394385dda88',
#  '8d9faaabfadcfa1c60bf',
#  '6bc0526a33e756e587ed',
#  '6eaba6dcffa941f1ccc8',
#  '1c8ce6a801b7843c2aa1',
#  'ab34d662dc394ee51f29',
#  '338c53f0e72b0b2daf42',
#  'c9bf731de2ddca08a8a7',
#  '3f40f381fe20e92ea21a',
#  '1605f6783f4c3e0ef2a1',
#  '9e80f1e50e6ebe2b601c',
#  '6dd9f023448007b4f7d6',
#  'f1f2af72ca218b3894ec',
#  '2ed546c62448a5edd6e8',
#  'fd66136918a7faed6b5a',
#  'af38a1ec666fc028ac02',
#  'a88c9d21b10b669410e1',
#  '314547323a9063ef0b02',
#  'de4532da530c194f2ace',
#  'c4cf55106368adf99dff',
#  '2636eb230b2f61be00eb',
#  'c18b99e6fa4c970a386a',
#  'b2f15fecad8760c26ec8',
#  '6bc3e8bb77bd18cb42ef',
#  '080ebdb00ed09cd028f5',
#  '60bfb2f7ea45fc0e022a',
#  'fd43c39888cc503aea51',
#  'ad50eba18721359a78c4',
#  '509507ff8ecbcb20dffa',
#  '4999d3c3b232a949ff80',
#  '1916640cfdfda180dbd4',
#  '5fd470fa6725fda46420',
#  'f06979f0259780e4a1db',
#  'ef2d0ad0f0ee8f682692',
#  '60944db3a6f9eede9d7f',
#  'e721e60d1ce271c3ae7a',
#  '031178b33bae1f83501d',
#  '76441df78cdac381f448',
#  '1959dede623f9459d03a',
#  'e36bea581241dd007adc',
#  '80ff851885aeb1621c84',
#  'fd4477031d0af8de2c66',
#  'ce442dbd7ee4fe51bb4c',
#  'c084939941429414446f',
#  'eb7fd9d3354c860f9070',
#  '38ef68adddfc0503368a',
#  'd14da72e065b3e7534bd',
#  '4f00681f78d205416777',
#  'd5736120d081cb9656ff',
#  '680d9c9797068b925abb',
#  '9161841e6fadfcb98792',
#  '5189adfaa3f161cf8d0c',
#  '586d43e1a92457a3b787',
#  '779771ef68f722e0dfd7',
#  '31fbe97ecaeabdd5f96d',
#  'db6c4df20d4e01c3f75b',
#  'b6a8a870c27ecd8caf54',
#  '8c798724f0fcf45c968f',
#  '903ce75a59fd1f4cccc3',
#  '0f25ba36d88c68f313c2',
#  'eee54a857650d4cf33cc',
#  '98298adde626fc2e0b50',
#  '3f77a430bde8a93edba8',
#  'e463188104f64afde350',
#  '9a37a7ca706f639ea7cd',
#  '29249bf6d3289d3530d5',
#  '552045bb2a125a334804',
#  '451496dbf1ab95f0a4bb',
#  '6ec0cdb441553b52ed16',
#  '1db6576e12dcc8b7aa1b',
#  '7e61dd53221cf6b7abfd',
#  '6b9bbbeef6fbd1a8bff9',
#  '0490a235061a5b13032b',
#  '12aac66e57fdf4cfc569',
#  '05de211655a1eda194a8',
#  '76ae651257e71dfcc8c8',
#  '968bf69091852b43de42',
#  '3ec9b26f309c0e504bb7',
#  'c569c79baceb615ef2b7',
#  '122ae31e3bccfaeb445a',
#  '7b2b1ad1110b291a1451',
#  '301d2195297d54b8cb64',
#  '21c66374cb7209c2f891',
#  'c519ba552c1e1a06e3fd',
#  '848a872b71b15db4baa6',
#  '02e60ebb440529e90891',
#  'e07e0e0ca5a0d1712680',
#  '4fef2e492e9100bce39f',
#  '0eb71b77d81a4d5b513d',
#  '2a3536cb9e4c02218677',
#  '9e500e4eb4eb2eafdf22',
#  'dc4bab0d5c59d1cd82c0',
#  'bc8d52b307efefe7561d',
#  '7f60061bf7a49aca7bec',
#  '0aa4283d1122e22afadf',
#  '784539e23eb24e00948a',
#  '88de43042ce06e65863c',
#  '6cdaba24663f3dd858e9',
#  '65bdbb29019cf6c23edb',
#  '251104e59f818313dc97',
#  'ccf20db29c5475a14f4e',
#  'ded3397b2f41eb47fc94',
#  'b05bdb126fde75b88077',
#  '058d11360688d0f74523',
#  'e30557c2eeab09cff57e',
#  'ac632a3ce7db4dd3cb93',
#  'ce2b2a67d1072deaf5aa',
#  '6bfa872c7ef13bcfd7b7',
#  '0c6e01ad0b4b07e9ba0b',
#  'bcad24d5758d133f3901',
#  'b4e11a98de95c2edc659',
#  '645dd73f2d6e4bbb36ce',
#  'e873b1638be2c79db6e4',
#  '4fe3aa53fe24d965ccf5',
#  '44078f0e7906b50632ca',
#  '2c6535627df54176a72f',
#  '6803012a87cadf4debbb',
#  'ef5ce5906968356cbeef',
#  '3339a803d7da4b83ad7e',
#  'ac986c4e5ea8c9cfa7af',
#  '8cb634ea495075888a3d',
#  'd79b7249464fd557791c',
#  '5aa50a5e1e6528c9ed6e',
#  'b363d7bc2c642b37cdf9',
#  '882abb36c8530ef11ab0',
#  '9ee35a1457cb93ce0f48',
#  'f7596ab3acceed7e9d29',
#  'f1e7454ba708d4d99d9e',
#  'f5f720f08624cb1bc701',
#  'c6d976201d38bfde4e06',
#  '4a288e0c07616dad846e',
#  '782351bf2afe27de6580',
#  '6df4541f83f872d62c8d',
#  '7fad5cec51cd3500d2fd',
#  'e0283dc8dd47f4526836',
#  'e1a2962c5aeb63bcab67',
#  '1802a24b72dc5cc62d79',
#  '76675edf241afa978a3d',
#  '4ad4f5bffd846a3d51d1',
#  'b8c9c1a8d123f91010e4',
#  'e36058291cd1d62f3af5',
#  'ea49cbbd7ad8bf43a453',
#  '72567bb55bade85e5e10',
#  '1cb78fe7fd6581fcc646',
#  '7e7a57ee2732be1dab59',
#  'ea1327346e0ad996b063',
#  'bd702cf44f3b1873fbf3',
#  'd3c959bc8410fd0c6779',
#  'ea1d870f371696292c75',
#  '3655fe0db5fd9748eb9d',
#  '6df2ace6cebb0aeb15e3',
#  '2090916962274c147136',
#  'b5e639e8edf07992d67a',
#  '17719ffcb26bcaa05257',
#  'cfcb390589997a2062a6',
#  'abb4a3a47231623be829',
#  '705f3560dd3454df8a95',
#  '5ebd8e949cfc254417b3',
#  '91fc862c0f432a0088f9',
#  '03c9eb8184b7826c7d49',
#  '2ab93d54bd9f18d53555',
#  '794fb3f1b64cffd128e2',
#  'c01789c40e604e5012ef',
#  '7dc5ffbf2832e9037a25',
#  '16e4d97ce495052d5fff',
#  '61cab453eab49a228355',
#  '8222ae85f7f1d8aacf91',
#  '9890947aedb496488286',
#  '590238ae2757595fccb9',
#  'e9ae11a424aacce0e07e',
#  '6dfe74c983ca98837e17',
#  'b61e8257b86aa7da895b',
#  'c4ee3a4778ec10c70132',
#  'faa7f16ec323fcf013c3',
#  '343e4d38642a2fbf1ec7',
#  '2cd56ca286d7da22c19d',
#  'f25a3d839a78bf076781',
#  'a172e3bc51dd9db6f4f7',
#  '5a86f325f711a57fb890',
#  '0610dd1543bb49aa493b',
#  '1f9263a3565462a2dd3f',
#  '1b9f0394cd2a19ed8d07',
#  '2fec42d45db1c4780948',
#  '26d14ff4c9f30a17c9be',
#  '84024719c3f231d1233e',
#  '82dee0f45e35221095c7',
#  'b8762a7dc780f11b47c0',
#  '9d33cfe922701eb50c38',
#  '7f82d0934fde27754fef',
#  '373d8fe13681ec7ca277',
#  '7abed3dec66c7967421e',
#  'ef9c51e80c42386af108',
#  '3f4747aac0d6f44c11c8',
#  '890a18006584815871bc',
#  '23604d4981cac03ae3d7',
#  'e902728c439e0e72571c',
#  '76245b316f7a0a8be4f9',
#  '839bf2c97b642268dfa2',
#  'fad304c32553f0da7c81',
#  'd40853ddd836abb3c778',
#  '7e629aaefb8c330a935e',
#  '01d3d3fa1e5c61299b49',
#  'dfa7417951556b7d9451',
#  '202022d8af14da3311b6',
#  'bda2bda27454e68e8174',
#  '47f47372efd282b6177b',
#  '7c92d742e924b472b25a',
#  'f7a8dba297d694ecbb2e',
#  '87c5bebf82454f0a309c',
#  '831b8b12f1c680f86d93',
#  'c8f3e6b0e6029f1e98e4',
#  'd46a48fd61b5b7b1c119',
#  '4d0e4c9514324d68e791',
#  '43c9cb9ceaa1e8e4f828',
#  '966782d95eebeb750bbf',
#  '3693aed04b6d90bf8ce8',
#  'cfc8be1d91dea0335d28',
#  '35983a835babd8e5a4b0',
#  '36f840fd1cc8e4b3a583',
#  '297c049ae967c0f56ff5',
#  '42786ffd9b9596fcb53d',
#  '2e0615f238a28429a4c5',
#  '33ba9f04500fed450c62',
#  'd1ee856b5de46cc901ab',
#  '1e9f24dfb6d2cd2f2007',
#  '494934613a6f892644e9',
#  'df1dd192d4be4009b5cd',
#  'ddd768ba07204b32e9f6',
#  '52cd70db7d06cf49f6f8',
#  'd4366645ae30cb8027e3',
#  '1e4cd427dd23c911c1f1',
#  '3f767d61443d658359b0',
#  '1e2c2375faf825dc0880',
#  'a9babe1d4d2084e2dafc',
#  '79047ee79d01ca601b34',
#  '3b52b6e528f454bb7aa2',
#  'c1c0121178215349d28e',
#  '73fd150d7fb359a3551d',
#  'f3ffc43bef238c830f2a',
#  'c2fb2210b4f838cd42c8',
#  '6c581ca9c1bb9fa9ee61',
#  'ded8a323ce157a9f139d',
#  '09063e94e1cad259881e',
#  '94c53ee7865f9413e5b2',
#  '40a371e8052a81fbb3bc',
#  '3cffccd2b996404e552b',
#  '287d91befbb0d6b8c354',
#  '6a5ae8bf7215207778d9',
#  '686833ee384cf63f1896',
#  '269c1c7792e57a761b66',
#  '5dfb9e19e11150276d6d',
#  '56ed9946a4b4fcf628b7',
#  '55da54c61c44f3909cf9',
#  '5f179d0bf7f67e2a8b21',
#  '80ee2a4d1fc46dd6942b',
#  'af7508aa91e393c30f5c',
#  'fcd22dcf8ff989b8e34f',
#  '1548a3b6e9d12f349ae8',
#  '3b28edbaf61e4a78d51f',
#  '291fb3fb6710f89a0ee9',
#  '70c04b9d7837db95dc2d',
#  'a9b4bec67e489af6939e',
#  '46a92711b6ca6963fbac',
#  'adc96462df711cee3a2e',
#  'ec5091f7dda94970cbb4',
#  '8a9529aecc1f072e5ede',
#  '284c439f2c69d94f6db9',
#  'bf9b47ad2158660dcfff',
#  '32199a680a3f0626a5ca',
#  '69407223f55c30654a69',
#  '40b578fc52253f38e878',
#  '40e9198132d881051bb8',
#  '7025340cceb8b7907630',
#  '6c4a59aba7d2df3d4bb5',
#  '70fc4a4dfdadddaec6e1',
#  'db015a54ded0ca4b2af2',
#  '9fc7fe1002972694d594',
#  'e262eedda60062090959',
#  '51591fd8467434ecbcf8',
#  'b14cd5c7fcf88a9f7cd4',
#  'b2e1b66dc163f2cb1ff4',
#  '560e7ebd7c3b27492b4a',
#  '3ad91e1d20211f0fcebb',
#  'ffa7f6d2c2d2cb9b3ea7',
#  'e7af4fe6140aeda62b2e',
#  'dfdfe1f920ff44d15d24',
#  'e164a86cee453f1a5535',
#  'fbde3a17d6ab4ae7a7e5',
#  'de693b3846c8880636f1',
#  '72c2d97a7257a71a90ff',
#  '21c5cf01c2ffb2e42fc9',
#  'a0186c0f1bed95afcce7',
#  '0a9b8ff091da4c270227',
#  '6eefa8dabbe5f206da78',
#  '62fcbeaa172d96df530b',
#  '10969d5bfefe73334d4c',
#  '9b511adf865ce4d20a01',
#  'ecf5aa75b5d179460954',
#  '16b736d33d7a50fa2b43',
#  'fe3a55a7a61007bd1cc9',
#  '8c51d83c8270f347e130',
#  '07b49bd2f327fab2cd07',
#  'ee7dcc930694e5e96af0',
#  'f29e6be01dac465fe627',
#  '7b36b1a406b60caa9346',
#  '744da752be60c1581959',
#  'f5b3539f221c0f95893b',
#  'dcdb0a8b72b2409ef1ca',
#  '5f9156675eb981f4888b',
#  '5e52a2f3d39c0ed6fe4b',
#  '6f3972b55860d19b02a7',
#  '464dc7732bfb5f5d00fd',
#  '2fe8541f1fd820900d0c',
#  'ed72f88ccf2f1623572a',
#  '9dcdf49ed88d4ad6befa',
#  '4655b646623992abb124',
#  'fea4b728897b2b168e01',
#  'cffe50923bd1bc816b48',
#  '66af34ffbf1575348c23',
#  '56f62fcc9bb98cfeaea2',
#  '0c54a275cbff40759b6c',
#  '9d40b801f7b24917528b',
#  '07fe9a43e8bde618160b',
#  '33a160bddc0353302a12',
#  '6ce17992314d582aa943',
#  '7e625d8ce0bbdfd7e035',
#  '0a4785bce85db8b8c90c',
#  '822deab3b37213ba4710',
#  '5d5485d95617f407a187',
#  'c2cd3ce64957b51e8717',
#  '9a51f05a2ad6495cdbd5',
#  '549c06cce46209214864',
#  '7f5bcb79e16a0e35d403',
#  'c70078bf6f1503253852',
#  'f21cf95fdd41fcf459c2',
#  'c2688423ee04b35ad368',
#  'e12288f1100841fc338c',
#  'f222ab30351015717211',
#  '2e545fc694f47f02fb4b',
#  '7f3e24c55875f6f6c202',
#  'de3f3397583bd13c249f',
#  'f60955257c4952361d6a',
#  'e17bff2fe71f8fa8fc8d',
#  'd0cfc17a749c43600222',
#  '6a76c1cbbe78f97770f0',
#  'e6422b1881b38f5d2349',
#  '2fb3877a347ad974923e',
#  'f2c1335b8a95f2b5bae4',
#  '5c606da0e6a9b7e462a8',
#  '60c434a614e5a8638224',
#  'f4170a3d5da353f7d161',
#  '960b6d4abfc755f1a88a',
#  '046c934768213ef61848',
#  'e9db0c7de9a68714bd5e',
#  'f98229441c9c7832de98',
#  '35082382e89a1dda5336',
#  '1c07f625629d2aba90bc',
#  '6514d47142a18ee755a8',
#  '453b93d03477bcc8be29',
#  'c5e59891219181332483',
#  'ab8be463cc9a1ecaffd4',
#  '4ce77eb6a54178dd1093',
#  '7aae4a5fae54aa5f0930',
#  '778e895ceabfe0242059',
#  '5720e6d6037cdba52a30',
#  'b7dc27e1657d377439ce',
#  'c5a3aca6ec3fa227440f',
#  '85869d60df552ada7d17',
#  '0e3f2706a72a9fbfa8cb',
#  '63d94f5c1d4fe0fad592',
#  'a8d4344fd561a3ce63e5',
#  'fb3f8e4523b5534cf2f5',
#  'a4a37d1b2ce5a24b042b',
#  '0ef6ea96c40703ba0beb',
#  '6b12a61ca6d8101e750d',
#  '947e218dee977a9fbae5',
#  '76fea2e8b0773a867576',
#  '179ae7016bd7ea3aed28',
#  '136cf589245384e7dffa',
#  'c437b50487ec4700d115',
#  'c6be8ec6697f57d48f9c',
#  '4bc3344f4182afcf8df5',
#  'f12241c2a1186dc5c2df',
#  '9faef26fc76f2c3de9b6',
#  'ad67a6a254fe97a25517',
#  '10f0c17253875d6af87d',
#  'd8cb7eca93c1f0c02cec',
#  '1f02d520ef4d98cae115',
#  'd362721afddbba7859ba',
#  '18863f31355134b7cbd0',
#  '2cd8daa33db2c3a20b16',
#  'ab56311afd1b7b90f94f',
#  '39e02c6b8591632fff9a',
#  '2b73be1ae2a0ef543353',
#  '45c1ab8773fe6e095d4c',
#  'ccad078b9ae1b52948e2',
#  'f07054f4114d87c1bc0d',
#  '7c9a3ae7907900a6870c',
#  '9cd3a673c9ebc6757905',
#  'd231a9cb0911b6b64f6c',
#  '876da8ecf624e0984cc4',
#  '35b1059be760d4e538b6',
#  'b517669108207242fee1',
#  '51b6c533e9aeff6d7b05',
#  'b8fa1371d44b39f8c816',
#  'ff6443be1b06483aad08',
#  '04a859d5eba012507493',
#  '3965f3e7fb528bfab5bb',
#  '681dd68a92c0944089d4',
#  'd31a3eee7fd4ecf2746c',
#  'f7303352f079443dde05',
#  '1d8adbf95fd698d483e1',
#  'b3db567b62e259c98c53',
#  '099bab51ef75c920f1f0',
#  '833e1dc82868b85ecf78',
#  '4ef5720b3eea643e38f3',
#  'e0f951545d229ad24a81',
#  '7023fc9cd663af76f3b9',
#  '4dab86e28f756c27be3f',
#  '15e2263f29880e853007',
#  '16c68bfbe26614035cff',
#  '4e79b65f47e78eee968a',
#  'e6312feeb6c3f3257d26',
#  '92171531be6da24a7acc',
#  '6733856f426891da4658',
#  '2aa530bb0199d2da0110',
#  'cc8592e4edf8aa64d35a',
#  '4ecd07be0f73e5da3e65',
#  '51bc5cb4ee8a6bcd9c99',
#  'dc609780457dc07e5e79',
#  'beff8a69212340b483d7',
#  'f3b9aa08a5464af8d282',
#  '69c4363fdc3a76c4ee92',
#  '9a45f2d54a1532bcff40',
#  '998b7478cfb0b67b2f71',
#  '3699221ded554d4853e1',
#  '9b6630bd225d95af0390',
#  '945378faee6d69cb370e',
#  '3f5785ec158090e3a4eb',
#  '2f0d6e171e1f8246c71c',
#  '5425c9af12f438a4da08',
#  'da5c1934c0e0db8b53c7',
#  'd43ed79151646899fdd2',
#  '567b8dd9be272f9260f6',
#  'a5c96c2fd6c5181dfa87',
#  'f57baf2bec5b0bc57511',
#  'bb1a4e891bc24f5570b2',
#  '7bf741bbfa316004424a',
#  'a40d3d7f0b7fa39b1520',
#  'fe888132cae712f498b5',
#  'cc144f9589d03a3827fa',
#  '85131fb4c68dbeee73db',
#  'eb75b5f353e47169bf97',
#  '457b2596dceccccfdc5c',
#  'f586b59e37ed2745749f',
#  'a3feb5c4d45dfad4f83a',
#  'b5c9cb0ae8518d86f880',
#  'b3c6dc3936ca420c714b',
#  '6bb1f027251b3cbda5aa',
#  'b5cfd52013fa2e0a523e',
#  '51c2be254592004f6083',
#  'ba4fe040d3bd4e508587',
#  '1eedaf05e0356f03303f',
#  'f5a0d0f4a5a9bdfe0f37',
#  '1181d993c76b42682e6f',
#  'bf75a2d6922168b7c730',
#  '7832d91934f3f0f0b947',
#  '99cdc39ca644448b109b',
#  'd07da3f886d466333c39',
#  '6a10066f24f762de114e',
#  '41fe09f2dd1d764cf507',
#  'e1e0a74c09d217150df4',
#  '2d3a120d5fcce122d42a',
#  '540c3ebac3e928f0c154',
#  '714222de59d880228c42',
#  '070267186382445aaedb',
#  '08f7f5d0a75f9e7b4ac6',
#  '38327cb61a0ae0674a91',
#  'fec6d25a22ecadc3be94',
#  '92686728d072d588ad58',
#  'a5f06ef83ef98986dace',
#  '253cf824964b443c0b6a',
#  'e77086842d8a558dc58d',
#  'c42be0c39cfa1b0066d6',
#  '1a68319748538b1bbcf2',
#  'd6dca106a9bbf067ef7b',
#  '713a673322dfc6f7b0d5',
#  'f7af21ea497807a04fa4',
#  'f0e63e1f050165c29d7f',
#  '297fd04a31f2985f41ee',
#  '61b03ea1c517f16d51f9',
#  'c7db2377e0e69a6d61c7',
#  'a383bff559cd0ef26dea',
#  'e34e83cd96da9ae30e1a',
#  'eb571b54d3e1c217e389',
#  'c58d30498763a2c14b0e',
#  '9a41a1a79490b5db37c1',
#  '8683bdb425fa49e273ac',
#  'bdf40d33b6cf5eb5c3ba',
#  '7e60758e1645bfc77047',
#  '299b87195bd6d9d5bd26',
#  'b3f6a822e7fc8ea1e828',
#  '076290150390e83b9611',
#  'b5d89df5dda8e52d1a63',
#  '4e23687325dca97e7620',
#  '7401455f20b857fb7d3f',
#  'dbacfec6f3d2c43abd6e',
#  '2af6fbb062938193d753',
#  '09a58952ee66ec010048',
#  'cf26769214f30fc7fa76',
#  '60946cf3ce1198323642',
#  '21aa674744b1eff1cbbe',
#  'd00ec535a6e2d794e165',
#  '4969625b3c8b6a2856ee',
#  'f104bf470e7558734da3',
#  '2aa83a982bf7abb85ada',
#  'cac5939a62f3ce5c0a8a',
#  '18c14736f4ac9eb4b22d',
#  '3f5ab652a676cdd3cdd3',
#  'ee482307a817fbae179b',
#  '706ba710ba8e0a567f9d',
#  'd7b498e5968f89a50dc6',
#  'bdf3fed84e17e3b25be1',
#  '86addd435abdbc6bf3a7',
#  'eeecfb205d6221a7070c',
#  'a776fb8726831c812b6a',
#  'cf16932908bb6c46c915',
#  '322473436a529b02f3f5',
#  'a234495a3462e3c034e3',
#  '112cfb8d27a5616b97b3',
#  'd517bd26a0b59d0493d9',
#  '7c9bd5ac572b3f29c92d',
#  'abeb296211015999875a',
#  '3c6bcdbcce13eed580c4',
#  '6600f6237922992b1f01',
#  '6dd64dc9921cfda8a14e',
#  '94472283d3ec0eb00078',
#  '956096d3a91a302d6936',
#  '262fb7740580d8ed1e00',
#  '892fffd6ace30bb9df06',
#  'fac08607dbbff89d5535',
#  '56048d62d89e2913ab44',
#  '8ec08ca4b96d7b4715ed',
#  'b0f444249d59b6573efe',
#  'a0ffa710b73fb6c6c322',
#  'daf5095f77e60db9def6',
#  'd91d59cbadf9b2c43ea5',
#  '19ad90a42883ac126b5c',
#  'a37ac285bd4a230b4a4a',
#  'b8fd0f8ac0b082b40e39',
#  '69ced32016eaf65e371f',
#  'c9b9dc2a95b58bc768e2',
#  '7dfefbbd1e2e9238e3c3',
#  'd5d2fad4cbfd2892e44b',
#  'f5b5f26931f68a678c12',
#  'f5e62aa525058a12ebc4',
#  '0f55a0f2c4129deac9f2',
#  'be4d6a1940d281947439',
#  '326a7e51943396fe5c67',
#  '35cea20e2ba70697ab18',
#  'e5bd87e429068fb05a08',
#  '673bdc86c0b4513c8777',
#  'fab795d2606cb3ac8cd8',
#  '9378fd38e27b99463fa0',
#  'f0891be1ea7c95c8438f',
#  'ccea25168b48393d0dd6',
#  'ab79be525da3b4c00b76',
#  '036386963dfe4f5030e7',
#  'a79126265072146bfbd4',
#  '626082bd693f47fbdf79',
#  'fc86eee8a13202eb5f4b',
#  '90a6cf233997f872f997',
#  '96a1f9eed669e8cfe573',
#  '9da9e7ca27ceef1f92f9',
#  '0e7e7b85c39de340015c',
#  'ebc6aad00b85d975ee44',
#  'b09efc83aab875ed3811',
#  '363e9e1d80179460877f',
#  '21ad9d22c580834a9ffb',
#  '118b589eb7df2d1a839f',
#  '6449cfaf6ba0f465fa87',
#  'ab2a7f122c94698291cc',
#  '946a393e02cb766fb78b',
#  '1087acfe2f60c747783b',
#  'cc76440fba3f073ed19e',
#  '0d0b08f19e170643c375',
#  '325c44ff754570254118',
#  'f9c71985c4bf74dc0fe5',
#  'c5c0858f40bd0949e39a',
#  '9ea68bdae31b06ff64a8',
#  '360a0d298faf598f3f27',
#  '8a685d6a870e4ce40140',
#  'ec389ebf18d91c727085',
#  '0ac453d36e3590ac00a0',
#  'f33060e571c2211ebed8',
#  '58a2b33d82be716161b5',
#  '640e87bc670f6f33935c',
#  '0a512d901fda5510aa3b',
#  '8fca5130afad8c9aa7dd',
#  '98a595446261055cdd20',
#  'fb4d4e851cbdb3e7deba',
#  '1c9c674ad5f6a33a1543',
#  '6e25120dc6795e621d00',
#  '60ece41a8b4b19222932',
#  '63cc6a849c61db6cbb06',
#  'bf174f83f8b53ba76922',
#  '5f41570471123247ee8b',
#  'ec8fd0443fd14a213480',
#  '30d041fe189a4163dffc',
#  '979a8004d8c59719b8cc',
#  '782af6eb627fdedfb511',
#  '0a3f0a7f9f5fb86885cd',
#  '499bca53382ff704a756',
#  '42b66cf7018e549d0c3d',
#  'c18f38badf0a5ae4ef1d',
#  '60f535ab4c2dc10c16a0',
#  '8fabefc0c60e28d259cc',
#  '786c2f4f9a9185d1f29d',
#  '6672e26587fa6f5bdfbc',
#  '8a5a4e4a617e8c78b6f0',
#  'cba7c264972fe8403d20',
#  '1265b683cda233025cc0',
#  '368199db419684598165',
#  'f4be12f8dd37e00cc877',
#  '4a02b3c413694df83dbb',
#  '8d0d835ad05aefe24260',
#  'f925eb1ea912170a0155',
#  '12911b8b2695286a2fb6',
#  '974e40a3b524fe37a56e',
#  'e5beb77bca0d9d69d9e2',
#  '1a9048270591ea0dcdcd',
#  'a782ea38142bacb232d5',
#  '0b9ca0e599a2f8b9e06d',
#  'bf9bd93154d9a8be95f8',
#  'b745920885af98b2ad6d',
#  '48479a6c49decefba68b',
#  '6d4293aa559015df4208',
#  'ff4b33fa1fa8a5451f9d',
#  '2826a6fd191957838caf',
#  '77d85b99f6a3f651ddd7',
#  '45805c8e9952543b20c4',
#  '95f09f32412d3641e633',
#  '474251fe5dbea25e6931',
#  '4af2496bbe2acc9f3d3b',
#  '1ef70644e70f1f0e71ce',
#  '8a6f33fe6cc5133c3ea8',
#  '93f2b22f2a2b725173d9',
#  'ed94e6ab6e7f0e7b4c87',
#  'a0906e7930bf243781e8',
#  'd7f338ddf6a4df0dc15c',
#  'afef59aa2edfc2746ce3',
#  '9b7b18e117001497c033',
#  '5b017692afaecb136b81',
#  '218877465cc4eb3ee4bb',
#  'f477d5082574c78557f2',
#  '36b21bb8a2be8ac3979b',
#  '9dad1359ffdf0f0872fe',
#  '2a194895e78335f0f425',
#  '5b7500176c483e1ea5be',
#  'cebd5c017ec1efa560f6',
#  '45450a76412fbeb1a464',
#  'd6d0a84effa34b734873',
#  '48cc6d0ea4b56e012fb5',
#  '27ed51ea23c05f726dfb',
#  '7e14692a9c46962c0645',
#  '7d517e2b5766d22d0f51',
#  '5df61a6ca7cca59fe358',
#  '1f19a3f19dbf555e1e8d',
#  'c84b47a3671518d707d2',
#  '590fc75c403d9c4c90dd',
#  'cbf42dbe42e2642c676d',
#  '3f23dda516f8c3362fd2',
#  '0811aa5cdf2723100e0a',
#  'f4f7eb182f8bd704e8a4',
#  '16f33f60871df3c0ba75',
#  'df594bb4d367cd638ecc',
#  '4dd9ba1ff5573a1a3c85',
#  '3faa14c882cf985e49ab',
#  '0b4bbd69f70a0e0cdfdb',
#  '4c7018f095467ff4062e',
#  '08a6270b364f07588fca',
#  '48fb82b859f7eb5a8608',
#  '98a066a4bad47134c714',
#  '2028749cedbcc2eafa15',
#  'd547d08a4b6d575472cc',
#  '555dc3e708795aaad8c4',
#  '51a8e98313d972122d15',
#  '65d79e229cec5b35f0d1',
#  '63564d6461c26003dad3',
#  'e3193e1cbf2010d4fff5',
#  '7efe37a0ee19d74e56a7',
#  'c7a53bc81269a41822af',
#  '6801b630d8e0b0bff69c',
#  'cf9d7908dd1e503048e1',
#  '295269578d3cac8ba569',
#  '3a00724561bfb2b1e4c4',
#  '8c973abc4f1df80855c0',
#  '0afb3ddfeaa16fd8a366',
#  '0e2d3ea2c234c2c2dcfb',
#  '812840f23aae265da1df',
#  '627fd3e9e2b31748ddd2',
#  '34e918cb69c389660301',
#  'd38fba67d702c12b30e4',
#  ...]

# %%
db.findOne(db.TABLE_FINGERPRINTS, {'song_fk':10})

# %%
db.findAll(db.TABLE_FINGERPRINTS, {'offset': b'\xe6\x00\x00\x00\x00\x00\x00\x00'})
# Out:
# [(2087, 1, '893ace4ef6414e388911', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (2369, 1, '203d17007dfe84698dbe', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (11433, 1, '5ef56b3236bb8c35b5e4', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (12841, 1, '5ac12ce784b0c0a0e111', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (13913, 1, '4641fa4396a428d9969a', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (14147, 1, 'b15da05ddba9ccd1392d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (16864, 1, 'fdeaf05816ecaa39ef4a', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (17179, 1, 'a63a9565403672f3052d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (17652, 1, '45d66c369f8178ee4688', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (19437, 1, '91cb1d3ebff71cc44b3f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (22024, 1, '555d74a992439520cf1f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (22980, 1, '903405b28e47d39f7791', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (25074, 1, '075156f14df2404fb34f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (26163, 1, '8540c8ccd3d48506be42', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (27209, 1, 'aa806644fafc1a0f5c73', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (31485, 1, '283b650e6a89a81fa26d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (31895, 1, 'aa0e05fc0a5656485708', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (32302, 1, 'ebe8d71766c44846e087', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (33334, 1, '9b1a0eea5d13c7d59e99', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (34231, 1, '852968d6aad95f05cf90', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (34495, 1, 'f98c1a0d7c7e69aa720d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (41122, 1, 'c86769d5ce929c67c86e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (41915, 1, 'd78060dc1e0566ee4046', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (42001, 1, '5b76d0bb6b4c742b8edf', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (43567, 1, '4101da0f1b42be3bdf72', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (44103, 1, 'c27a7206d516abd3e305', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (44139, 1, '9244e8f8b98a596be1e3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (45998, 1, 'f3e47f983bd62ac611a8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (48911, 1, '0588a3375fe5bc0a32b1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (49482, 1, 'f366897c5d82dffce5c1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (49805, 1, '16fe048542e89e572f30', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (50630, 1, 'b6bd65ede1516549393d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (52172, 1, 'e395f69401b87be030ee', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (55446, 1, '9b4431a482db792d4bf2', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (57771, 1, 'a89e44a6add7355da64a', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (60917, 1, '79567074b69ffd263596', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (61792, 1, 'c5097dec3ee9a06ef845', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (63100, 1, '0ba81c9a95486a39de03', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (63979, 1, '6a907ec4f4b83aa0785e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (66774, 1, '5ba74e3161ce3e80fc42', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (67390, 1, 'c766a44758deb58304c4', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (67551, 1, '06273af63199201741c1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (67557, 1, '2ad7b96d9e46f5191539', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (73998, 1, 'a9b88df044e93fff1a55', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (75897, 1, 'c4941a27c4892cb7b7c1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (77600, 1, '90195636954544455046', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (79997, 1, '3326219c8a46cdae1a83', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (80933, 1, '46663bffa83cfc4703fe', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (89267, 1, '907efacb664f09621aae', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (93850, 1, 'e001da81e6e4e5fdd0e8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (95144, 1, 'd9b275c33744e06f6afc', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (95559, 1, '40caee9dfd7e41dc2a71', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (97841, 1, 'c9215eeb3c09e1fbdd54', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (99403, 1, '30edc245fd10b57d088d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (101939, 1, 'e026f19ff06dea0eb088', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (101989, 1, '390333ef21b21a99a737', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (102318, 1, 'e786cef8f926b0d33f82', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (106036, 1, '2fe0d3d695dece2ae43a', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (106268, 1, '3c8a2e117b63e7fcfdb1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (112693, 1, '5fff206acfb142dadee7', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (113720, 1, 'dc9340f8cfd6de653661', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (114688, 1, 'f21537d7ad04d173b3df', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (115592, 1, '6fce511c4ef45ec6a168', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (118783, 1, '2f82382196eea96fb8a2', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (119183, 1, '573d40acf2d89e62f25c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (119622, 1, 'e318dcadd1600660b6d5', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (125582, 1, 'f9ff2a5f79017b92e8a3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (128253, 1, 'b4e8f54cbceff0135142', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (130084, 1, '3d9a974c5ec6b1e50c8c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (130950, 1, '12e29ebc18f664a7e253', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (131453, 1, 'a68933e9555f85eb7056', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (132177, 1, 'c0030f730476185a3665', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (133470, 1, '6f2e1480d1c5d9b7393a', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (134661, 1, '94d9d2610c5f284a4ef3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (140812, 1, '0cac2b99b2ee407ea9a8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (144981, 1, '578bebe6b8b6f593c17e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (148029, 1, '7bc5fd1368bb6d9866d7', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (148646, 1, '44a3da796f5383edeaf1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (153940, 1, 'c5194ba5a1724f5625ee', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (155562, 1, '56eef74d17f33823d5f7', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (156319, 1, '1e98717ae368e90a8e36', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (156452, 1, '2d6d54631418963100bf', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (159488, 1, 'b44f274de62c66202639', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (160087, 1, 'b50645a244c05de1b911', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (162265, 1, '2a2f0509fda3eb4c7871', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (163829, 1, 'fcd667c0eb7e80716a83', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (163837, 1, 'a95509337d2692e56133', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (172219, 1, '3cee768fb3823de5255e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (174346, 1, 'c42f96918c24a83cca57', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (175263, 1, '668db97ffc652b5507b5', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (176437, 1, 'ccc70de34b37224d8465', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (176740, 1, '09e25f0addea1f75fc33', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (181049, 2, '7355a2ceab41488ab6f4', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (182789, 2, '47cf709cb4e47d23356c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (184306, 2, '74e0170c66f4c05155b0', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (185202, 2, '28259deb933b2272ddac', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (187723, 2, 'b4e8f810b8f81dde265e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (189473, 2, '5e9c5c2a24d0421c8bfc', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (192355, 2, 'd1b5bc6857322a061e91', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (194070, 2, '1798512a7364b3dbf5a3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (205077, 2, '46afd933ec6e44bbafee', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (205902, 2, '2526dad90d46cdca48ad', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (214561, 2, 'd8751f380da30335276b', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (215218, 2, 'd2c504286ce145cdafd9', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (215948, 2, '2a2de14bcc018fd260ff', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (218500, 2, 'e5cec7ea011f5ceaef6d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (218650, 2, 'f1584d9f5db912f52ce5', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (221327, 2, '4c707fee83c4ed2c05ad', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (221808, 2, 'cfde0dd6583e3f48a64b', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (227084, 2, '53cc9c0a057556885c18', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (228806, 2, 'd30e3807034a07416e52', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (233040, 2, '869956b832cfb531fef4', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (234412, 2, '7538fdea5fc7be298f3c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (235114, 2, '3ad7ed8cc45e5be2bc31', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (238570, 2, '8d70400baf4407ec2087', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (244190, 2, 'c3aa3d784124b49bebd8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (246090, 2, '92c5ae490d2cbee18ea3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (246603, 2, 'dfa092daae1e31716b95', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (253142, 2, '86d861119757bfe9ca87', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (255184, 2, '030a1912187d00b4767e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (258609, 2, 'd360b1c8765524e2b0e5', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (258785, 2, 'a1f40faf0f43897f979c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (260217, 2, 'b1a56d8121154fbc031f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (265388, 2, '312e224d65759095100c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (271462, 2, '148675499400ace83dcb', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (274498, 2, 'bfb95b81cfb8da479042', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (281838, 2, 'ba8f8eeb10df7ff10206', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (282593, 2, 'df16fe3d9977cf5f5981', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (283531, 2, '71fe5b03e30e2a6d0a12', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (285693, 2, '0876320e03a973ccdc6f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (286358, 2, '3e01d42ae56f1d7e190a', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (287706, 2, '7a104a52fcbbf06c081f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (288775, 2, '38ac3cbd35d1ca0c1138', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (292691, 2, '4aa92b3f60b3c6ed75c2', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (296166, 2, 'de9dcbd4e158f02e7c3c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (296409, 2, 'cd8d3481204b67dd1436', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (298052, 2, 'b4f7b41fe5a274997b22', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (300836, 2, '880f3d822a320ea2ccf7', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (302676, 2, '7a09984f276dc27e3422', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (307703, 2, 'c945dccd08392e4d3341', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (307752, 2, 'e6cf89148a631cb88a1e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (310100, 2, '828c29cc4a113f3f49a3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (310197, 2, 'b9ca56366c3b77657ce4', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (312860, 2, '7721e7f0bafd6290fc25', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (317902, 2, '55f190d1c56cee6c4a5f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (318596, 2, '9c929de5a3a515313fae', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (325305, 2, '47c4fa7bf267ed5b81d0', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (326372, 2, 'e46f05932f0323f32ed8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (326747, 2, 'daac168c1ccea14ce066', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (327328, 2, '3d7d8add75dd62bafabf', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (327566, 2, '8f2da3e22f4d20d86c54', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (327992, 2, 'dd3aca2053b9cec73185', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (339574, 2, '931f92b563a12adddd1d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (340774, 2, 'e163407711cdb7189d8e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (342246, 2, 'd9d7368c81bd2215fc76', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (342276, 2, 'b1be0e2a5215de5c4bd8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (343913, 2, '2072db87caf4775d5750', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (344544, 2, 'bd445595b7cec8f551a8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (345348, 2, '4808bbe52bdad93d568b', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (346263, 2, '89693edebf4c1162b29e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (353389, 2, 'fa17c366579f1b1dd51b', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (355718, 2, '734292de461fd420cb25', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (361021, 2, '6a70d755adf325af7fd0', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (362572, 2, '3e85acbcf756dc9c47d4', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (364344, 2, '333ae413f0fdc2a98da1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (368813, 2, '7e9a1059c6335d34cf52', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (369899, 3, '02adafe45b9af35bdbbb', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (371141, 3, 'f80a3f4520552298c737', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (374182, 3, '658b83ea1206976dca95', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (374297, 3, 'b4037b076da62be3515c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (374697, 3, 'abf2f3b08d3e1c16ff4e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (376139, 3, 'bdbba27d0315e6923b32', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (378502, 3, 'bd4269c9a13abdede4b1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (380348, 3, 'b8c0f195f911bc4a0327', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (383384, 3, 'b62990781848a1a13095', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (383436, 3, '46db0cdc8b66e73fbac5', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (385547, 3, '728e0b2a161da5aab67e', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (388150, 3, '3f75e56f2b9679b23966', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (388703, 3, '5bf0c23095613f3689fe', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (389904, 3, '1cc114d73113bd70936b', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (390513, 3, '167bd4e0b99897b4598d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (390541, 3, 'e1ecdd31e9e2f18cf664', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (394724, 3, '43d15f95a0cf8197de4c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (395929, 3, '1c2e38de485041dfaad1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (399089, 3, 'afb601cd2265f81a8fa3', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (400682, 3, '3ab724546f02501961b1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (402290, 3, '97cdbe66bbb147784f84', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (402305, 3, 'b3c8d3592c4f53019a55', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (404337, 3, '93354c726c2669339d57', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (407076, 3, '0ed1f645c0c29f52c92c', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (407718, 3, 'b5f2b75641ca314b6a74', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (409568, 3, '0dd1c1a3c3fd3760f265', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (411473, 3, 'f1bcececf907066adff2', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (411893, 3, '81ac5b4106e34c588060', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (412619, 3, '6af1ffbd710368472e61', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (420499, 3, '0f07486b49e4da25e80f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (421599, 3, '531c14c1dc0c7c02b0fa', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (423117, 3, '8fecf21e55eb31f9dcf8', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (424175, 3, '82b4aed795708b04900d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (425130, 3, '05b3c8647fa087123174', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (425359, 3, '87a41ad5508841af3482', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (427101, 3, 'c4d8acb52d732d66c0a5', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (429672, 3, 'd4a239ee437b414181f9', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (429913, 3, 'e8e433c3c58ae6225ece', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (433522, 3, '909cabbe33e11a79110d', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (434079, 3, 'e255020c3fb34a9f921f', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (434136, 3, '9435d781f67cdd37bbd1', b'\xe6\x00\x00\x00\x00\x00\x00\x00'),
#  (437529, 3, 'be19b567d1eacc04bcab', b'\xe6\x00\x00\x00\x00\x00\x00\x00')]

# %%
int('\xe6\x00\x00\x00\x00\x00\x00\x00')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e7b253050c0b> in <module>
# ----> 1 int('\xe6\x00\x00\x00\x00\x00\x00\x00')
#
# ValueError: invalid literal for int() with base 10: 'æ\x00\x00\x00\x00\x00\x00\x00'

# %%
tmp = db.cur.execute('PRAGMA TABLE_INFO(fingerprints)')
tmp.fetchall()
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'song_fk', 'INTEGER', 0, None, 0),
#  (2, 'hash', 'TEXT', 0, None, 0),
#  (3, 'offset', 'INTEGER', 0, None, 0)]

# %%
int('0x00', 16)
# Out:
# 0

# %%
db.insertMany('fingerprints', ['song_fk', 'hash', 'offset'], [(10, '0000000000000000000{0}'.format(s+1),1) for s in range(6)])

# %%
db.findAll('fingerprints', {'hash':'00000000000000000004'})
# Out:
# []

# %% [markdown]
# # MWE ?

# %%
song_id = 10
values = [(song_id, hash, offset) for hash, offset in hashes]
# [h for h, _ in zip(values, range(10))]

# %%
db.store_fingerprints(values)

# %%
from tqdm import tqdm_notebook as tqdm
import numpy as np
tmp = []
nb = len(values)
for ind in tqdm(np.random.choice(nb, 300), total = nb):
    _, tmp_hash, tmp_offset = values[ind]
    r = db.findOne(db.TABLE_FINGERPRINTS, {'song_fk': 10, 'hash': tmp_hash})[3]
    tmp.append([r, tmp_offset])
# Out:
# HBox(children=(IntProgress(value=0, max=100765), HTML(value='')))

# %%
binay = [t[0] for t in tmp]
decimal = [t[1] for t in tmp]

# %%
for s, s_ref,_ in zip(binay, decimal, np.random.choice(nb, 300)):
    db.cur.execute("SELECT CAST(? as numerical)", (s,))
    print(db.cur.fetchall()[0][0], s_ref)
# Out:
# 0 1644
# 0 1572
# 0 1253
# 6 1078
# 0 1003
# 0 1090
# 0 121
# 0 1035
# 0 1277
# 0 644
# 0 367
# 0 92
# 0 620
# 0 805
# 0 9
# 0 1205
# 0 1133
# 0 1038
# 0 1423
# 0 144
# 0 378
# 8 1336
# 0 276
# 0 681
# 0 170
# 0 1035
# 0 1584
# 0 993
# 0 910
# 0 688
# 0 1719
# 0 1387
# 0 797
# 0 329
# 0 926
# 9 1337
# 0 932
# 0 291
# 0 1072
# 0 1790
# 0 249
# 0 1022
# 0 765
# 7 1079
# 0 168
# 0 1206
# 4 52
# 0 1427
# 0 71
# 0 1068
# 0 253
# 0 1088
# 0 764
# 0 368
# 0 1448
# 0 183
# 0 39
# 0 217
# 0 767
# 0 792
# 0 705
# 0 454
# 0 122
# 0 1443
# -0.0 1581
# 0 165
# 0 770
# 0 1421
# 0 1447
# 0 911
# 0 1177
# 0 1061
# 0 1418
# 0 666
# 2 306
# 0 214
# 0 849
# 0 835
# 0 959
# 0 1780
# 0 1143
# 0 1040
# 0 577
# 0 103
# 0 144
# 0 326
# 0 1532
# 0 1204
# 0 383
# 0 97
# 0 272
# 0 1165
# 0 1183
# 0 1003
# 0 833
# 0 962
# 0 144
# 0 1314
# 0 1067
# 0 710
# 0 1114
# 0 797
# 0 1529
# 0 892
# 0 708
# 0 123
# 0 501
# 0 1446
# 0 445
# 0 553
# 0 892
# 0 1112
# 0 1708
# 0 723
# 0 1341
# 0 79
# 0 667
# 0 1744
# 1 1329
# 0 519
# 0 1403
# 0 107
# 0 161
# 0 1723
# -0.0 1325
# 0 757
# 0 479
# 0 1205
# 9 569
# 0 1071
# 0 687
# 0 289
# 0 146
# 0 324
# 0 705
# 0 775
# 0 734
# 0 847
# 0 1361
# 0 1235
# 0 1264
# 0 526
# 0 1487
# 0 558
# 0 920
# 0 1708
# 0 1797
# 0 1740
# 0 193
# 0 1340
# 0 1810
# 0 956
# 0 849
# 0 1374
# 0 909
# 0 145
# 0 1207
# 0 1595
# 0 1365
# 0 1026
# 0 445
# 0 970
# 0 339
# 0 111
# 0 1072
# 0 966
# 0 666
# 0 1708
# 0 1061
# 0 406
# 0 1470
# 0 1234
# 0 269
# 0 626
# 0 324
# 0 109
# 0 639
# 0 680
# 0 512
# 0 376
# 0 1720
# 0 122
# 0 1566
# 0 13
# 0 494
# 0 416
# 0 1719
# 0 881
# 0 1051
# 0 655
# 0 1061
# 0 797
# 0 974
# 0 655
# 0 949
# 0 769
# 0 214
# 0 1029
# 0 290
# 0 323
# 0 1273
# 0 372
# 0 790
# 0 1050
# 0 255
# 0 596
# 0 72
# 9 1081
# 0 790
# 0 1522
# 0 37
# 0 441
# 0 416
# 0 620
# 0 1546
# 0 1788
# 0 1768
# 0 215
# 0 432
# 0 581
# 0 1089
# 0 666
# 0 1822
# 0 418
# 0 653
# 0 272
# 0 162
# 0 123
# 0 1720
# 0 1829
# 0 290
# 0 1299
# 4 1588
# 0 1021
# 0 387
# 0 1276
# 0 560
# 0 939
# 0 405
# 0 1411
# 0 960
# 0 1041
# 0 5
# 0 609
# 0 795
# 0 138
# 0 245
# 0 263
# 0 732
# 0 740
# 0 1209
# 0 1442
# 0 757
# 0 879
# 0 385
# 0 1565
# 0 420
# 0 289
# 0 1230
# 0 183
# 0 1130
# 0 1358
# 0 229
# 0 650
# 0 666
# 0 1393
# 0 503
# 0 1031
# 0 1204
# 0 705
# 0 1300
# 0 1204
# 0 460
# 0 797
# 0 369
# 0 1319
# 0 1172
# 0 184
# 0 1041
# 0 1675
# 0 911
# 0 202
# 0 1272
# 0 1171
# 0 1192
# 0 806
# 0 1772
# 0 868
# 0 163
# 0 296
# 0 1607
# 0 441
# 0 473
# 0 1532
# 0 756
# 0 832
# 0 470
# 0 1338
# 0 498
# 0 764

# %%
db.insertMany('fingerprints', ['song_fk', 'hash', 'offset'], [(10, '0000000000000000000{0}'.format(s),int(o))
                                                              for o,s in zip(decimal, range(6))])

# %%
db.findAll('fingerprints', {'hash':'00000000000000000005'})
# Out:
# [(539101, 10, '00000000000000000005', b'B\x04\x00\x00\x00\x00\x00\x00'),
#  (539107, 10, '00000000000000000005', 1),
#  (539113, 10, '00000000000000000005', 1090)]

# %%
db.insertMany('fingerprints', ['song_fk', 'hash', 'offset'], [(10, '0000000000000000000{0}'.format(s),1)
                                                              for o,s in zip(decimal, range(6))])

# %%
print(decimal[0:6])
db.cur.execute("SELECT CAST(? as blob)", (1090,))
db.cur.fetchall()
# Out:
# [1644, 1572, 1253, 1078, 1003, 1090]
# [(b'1090',)]

# %%
':\x07\x00\x00\x00\x00\x00\x00'.split("\x")
# Out:
#   File "<ipython-input-73-1b1a6828059f>", line 1
#     ':\x07\x00\x00\x00\x00\x00\x00'.split("\x")
#                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \xXX escape

# %%
b':\x07\x00\x00\x00\x00\x00\x00'.decode('utf8')[1:].replace('\\x', '')
# Out:
#   File "<ipython-input-90-18907b142bd8>", line 1
#     b':\x07\x00\x00\x00\x00\x00\x00'.decode('utf8').encode('raw')[1:].replace('\x', '')
#                                                                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \xXX escape
